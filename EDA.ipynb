# %%
import pandas as pd
import json

# Cargar los archivos CSV
df = pd.read_csv('movies_dataset.csv')  # Reemplaza 'movies_1.csv' con el nombre correcto de tu archivo
df_credits = pd.read_csv('credits.csv')  # Reemplaza 'df_credits.csv' con el nombre correcto de tu archivo
df_combines = pd.read_csv('combined')
# Out:
# C:\Users\jeiso\AppData\Local\Temp\ipykernel_6512\2580082794.py:5: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('movies_dataset.csv')  # Reemplaza 'movies_1.csv' con el nombre correcto de tu archivo

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df_credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
df_combined.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres     id original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844                en
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602                en
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357                en
# 4                     [{'id': 35, 'name': 'Comedy'}]  11862                en
#
#                                             overview  popularity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
df.describe(include='all')
# Out:
#         adult                              belongs_to_collection budget  \
# count   45466                                               4494  45466
# unique      5                                               1698   1226
# top     False  {'id': 415931, 'name': 'The Bowery Boys', 'pos...      0
# freq    45454                                                 29  36573
# mean      NaN                                                NaN    NaN
# std       NaN                                                NaN    NaN
# min       NaN                                                NaN    NaN
# 25%       NaN                                                NaN    NaN
# 50%       NaN                                                NaN    NaN
# 75%       NaN                                                NaN    NaN
# max       NaN                                                NaN    NaN
#
#                                genres                     homepage      id  \
# ...

# %%
df.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df[['title', 'release_date', 'budget', 'revenue']].head()
# Out:
#                          title release_date    budget      revenue
# 0                    Toy Story   1995-10-30  30000000  373554033.0
# 1                      Jumanji   1995-12-15  65000000  262797249.0
# 2             Grumpier Old Men   1995-12-22         0          0.0
# 3            Waiting to Exhale   1995-12-22  16000000   81452156.0
# 4  Father of the Bride Part II   1995-02-10         0   76578911.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualización de datos faltantes en df
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Datos faltantes en df')
plt.show()

# %%
# Visualización de datos faltantes en df_credits
plt.figure(figsize=(10, 6))
sns.heatmap(df_credits.isnull(), cbar=False, cmap='viridis')
plt.title('Datos faltantes en df_credits')
plt.show()

# %%
# Visualización de datos faltantes en df_combined
plt.figure(figsize=(10, 6))
sns.heatmap(df_combined.isnull(), cbar=False, cmap='viridis')
plt.title('Datos faltantes en df_combined')
plt.show()

# %%
# Asegurarse de que las fechas estén en el formato correcto
df_combined['release_date'] = pd.to_datetime(df_combined['release_date'], errors='coerce')

# %%
# Extraer el mes de la columna release_date
df_combined['release_month'] = df_combined['release_date'].dt.month

# %%
# Crear un DataFrame con la cantidad de filmaciones por mes
filmaciones_por_mes = df_combined['release_month'].value_counts().sort_index()

# %%
# Graficar la cantidad de filmaciones por mes
plt.figure(figsize=(12, 6))
sns.barplot(x=filmaciones_por_mes.index, y=filmaciones_por_mes.values, palette='viridis')
plt.xlabel('Mes')
plt.ylabel('Cantidad de Filmaciones')
plt.title('Cantidad de Filmaciones por Mes')
plt.xticks(ticks=range(12), labels=['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre'])
plt.show()
# Out:
# C:\Users\jeiso\AppData\Local\Temp\ipykernel_17680\1496491348.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=filmaciones_por_mes.index, y=filmaciones_por_mes.values, palette='viridis')

# %%
# Extraer el día de la semana de la columna release_date
df_combined['release_day'] = df_combined['release_date'].dt.dayofweek

# %%
# Crear un DataFrame con la cantidad de filmaciones por día de la semana
filmaciones_por_dia = df_combined['release_day'].value_counts().sort_index().reset_index()
filmaciones_por_dia.columns = ['Día', 'Cantidad de Filmaciones']

# %%
# Mapear los días de la semana a sus nombres
dias_semana = {0: 'Lunes', 1: 'Martes', 2: 'Miércoles', 3: 'Jueves', 4: 'Viernes', 5: 'Sábado', 6: 'Domingo'}
filmaciones_por_dia['Día'] = filmaciones_por_dia['Día'].map(dias_semana)

# %%
# Graficar la cantidad de filmaciones por día de la semana
plt.figure(figsize=(12, 6))
sns.barplot(x=filmaciones_por_dia['Día'], y=filmaciones_por_dia['Cantidad de Filmaciones'], palette='plasma')
plt.xlabel('Día de la Semana')
plt.ylabel('Cantidad de Filmaciones')
plt.title('Cantidad de Filmaciones por Día de la Semana')
plt.show()
# Out:
# C:\Users\jeiso\AppData\Local\Temp\ipykernel_17680\1512598782.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=filmaciones_por_dia['Día'], y=filmaciones_por_dia['Cantidad de Filmaciones'], palette='plasma')

# %%
# Graficar el score promedio de las películas con escala logarítmica en el eje x
plt.figure(figsize=(12, 6))
sns.histplot(df_combined['popularity'].dropna(), bins=50, kde=True, color='blue')
plt.xlabel('Score (Popularidad)')
plt.ylabel('Cantidad de Películas')
plt.title('Distribución del Score de las Películas')
plt.xscale('log')
plt.show()

# %%
# Graficar la cantidad de votos con un box plot
plt.figure(figsize=(12, 6))
sns.boxplot(x=df_combined['vote_count'].dropna(), color='green')
plt.xlabel('Cantidad de Votos')
plt.title('Distribución de la Cantidad de Votos de las Películas')
plt.xscale('log')  # Usar escala logarítmica para una mejor visualización
plt.show()

# %%
# Graficar el promedio de votaciones
plt.figure(figsize=(12, 6))
sns.histplot(df_combined['vote_average'].dropna(), bins=50, kde=True, color='purple')
plt.xlabel('Promedio de Votaciones')
plt.ylabel('Cantidad de Películas')
plt.title('Distribución del Promedio de Votaciones de las Películas')
plt.show()

# %%
# Crear una columna 'return' para el retorno de inversión (revenue / budget)
df_combined['return'] = df_combined['revenue'] / df_combined['budget']

# %%
# Función para desanidar y manejar errores
def extract_cast_or_crew(column):
    if pd.isna(column) or column == '[]':
        return []
    else:
        try:
            items = json.loads(column.replace("'", '"'))
            return [item['name'] for item in items]
        except json.JSONDecodeError:
            return []

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45538 entries, 0 to 45537
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4500 non-null   object
#  1   budget                 45538 non-null  int64
#  2   genres                 45538 non-null  object
#  3   id                     45538 non-null  int64
#  4   original_language      45527 non-null  object
#  5   overview               44584 non-null  object
#  6   popularity             45535 non-null  float64
#  7   production_companies   45535 non-null  object
#  8   production_countries   45535 non-null  object
#  9   release_date           45451 non-null  object
#  10  revenue                45535 non-null  float64
#  11  runtime                45278 non-null  float64
#  12  spoken_languages       45535 non-null  object
#  13  status                 45454 non-null  object
# ...

# %%
valores_unicos_status = df_combined['status'].unique()
print("Valores únicos en la columna 'status':")
print(valores_unicos_status)
# Out:
# Valores únicos en la columna 'status':
# ['Released' nan 'Rumored' 'Post Production' 'In Production' 'Planned'
#  'Canceled']

# %%
df_credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
def explorar_columna_crew(df, num_filas=5):
    # Imprimir algunas filas de la columna 'crew'
    print(df['crew'].head(num_filas))

# Ejecutar la función para explorar la columna 'crew'
explorar_columna_crew(df_credits, num_filas=10)
# Out:
# 0    [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1    [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2    [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3    [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4    [{'credit_id': '52fe44959251416c75039ed7', 'de...
# 5    [{'credit_id': '52fe4292c3a36847f802916d', 'de...
# 6    [{'credit_id': '52fe44959251416c75039da9', 'de...
# 7    [{'credit_id': '52fe46bdc3a36847f810f797', 'de...
# 8    [{'credit_id': '52fe44dbc3a36847f80ae0f1', 'de...
# 9    [{'credit_id': '52fe426ec3a36847f801e14b', 'de...
# Name: crew, dtype: object

# %%
def separar_columna_crew(df):
    # Crear una lista para almacenar los datos expandidos
    crew_data = []

    # Iterar sobre las filas del dataframe
    for index, row in df.iterrows():
        # Convertir la columna 'crew' a una lista de diccionarios
        try:
            crew_list = json.loads(row['crew'].replace("'", '"'))
        except json.JSONDecodeError:
            continue
        
        # Agregar los datos expandidos a la lista
        for crew_member in crew_list:
            crew_member['movie_id'] = row['id']  # Agregar el ID de la película para referencia
            crew_data.append(crew_member)

    # Crear un nuevo dataframe a partir de la lista de datos expandidos
    df_crew_expanded = pd.DataFrame(crew_data)
    return df_crew_expanded

# Separar la columna 'crew' en el dataframe 'df_credits'
df_crew_expanded = separar_columna_crew(df_credits)

# Mostrar las primeras filas del nuevo dataframe
df_crew_expanded.head()
# Out:
#                   credit_id department  gender     id           job  \
# 0  5462510ec3a368082d000121    Writing       2   6210        Writer
# 1  52fe46d29251416c75084b07  Directing       2  56710      Director
# 2  54625118c3a368081300010e    Writing       2  56710    Adaptation
# 3  52fe44669251416c9100f5a3  Directing       2  33315      Director
# 4  546110c3c3a3686f31000401    Writing       2   6210  Theatre Play
#
#                   name                      profile_path  movie_id
# 0  William Shakespeare  /2z4njqosEQM4g26ttb9grG9rJUg.jpg     16420
# 1        Oliver Parker  /3qdUN7qhcQn4P3tEOTKJgTUdCIr.jpg     16420
# 2        Oliver Parker  /3qdUN7qhcQn4P3tEOTKJgTUdCIr.jpg     16420
# 3    Richard Loncraine  /j700yY5SyI1EZegFpL4h77Otu5W.jpg     31174
# 4  William Shakespeare  /2z4njqosEQM4g26ttb9grG9rJUg.jpg     31174

# %%
# Separar la columna 'crew' en el dataframe 'df_credits'
df_crew_expanded = separar_columna_crew(df_credits)

# Renombrar la columna 'name' a 'director'
df_crew_expanded.rename(columns={'name': 'director'}, inplace=True)

# Mostrar las primeras filas del nuevo dataframe
df_crew_expanded.head()
# Out:
#                   credit_id department  gender     id           job  \
# 0  5462510ec3a368082d000121    Writing       2   6210        Writer
# 1  52fe46d29251416c75084b07  Directing       2  56710      Director
# 2  54625118c3a368081300010e    Writing       2  56710    Adaptation
# 3  52fe44669251416c9100f5a3  Directing       2  33315      Director
# 4  546110c3c3a3686f31000401    Writing       2   6210  Theatre Play
#
#               director                      profile_path  movie_id
# 0  William Shakespeare  /2z4njqosEQM4g26ttb9grG9rJUg.jpg     16420
# 1        Oliver Parker  /3qdUN7qhcQn4P3tEOTKJgTUdCIr.jpg     16420
# 2        Oliver Parker  /3qdUN7qhcQn4P3tEOTKJgTUdCIr.jpg     16420
# 3    Richard Loncraine  /j700yY5SyI1EZegFpL4h77Otu5W.jpg     31174
# 4  William Shakespeare  /2z4njqosEQM4g26ttb9grG9rJUg.jpg     31174

# %%
# Realizar la unión (merge) de los dataframes en base a las columnas 'movie_id' y 'id'
df_merged = pd.merge(df_combines, df_crew_expanded, left_on='id', right_on='movie_id', how='left')

# Mostrar las primeras filas del dataframe resultante
df_merged.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres   id_x original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844                en
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602                en
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357                en
# 4                     [{'id': 35, 'name': 'Comedy'}]  11862                en
#
#                                             overview  popularity  \
# ...

# %%
# Visualización de datos faltantes en df_combined
plt.figure(figsize=(10, 6))
sns.heatmap(df_merged.isnull(), cbar=False, cmap='viridis')
plt.title('Datos faltantes en df_combined')
plt.show()

# %%
# Verificar la cantidad de datos faltantes por columna
df_merged.isnull().sum()
# Out:
# belongs_to_collection    44580
# budget                       0
# genres                       0
# id_x                         0
# original_language           12
# overview                  1038
# popularity                   3
# production_companies         3
# production_countries         3
# release_date                88
# revenue                      3
# runtime                    278
# spoken_languages             3
# status                      88
# tagline                  27879
# title                        3
# vote_average                 3
# vote_count                   3
# cast                     39883
# crew                     41047
# credit_id                41047
# department               41047
# gender                   41047
# id_y                     41047
# job                      41047
# director                 41047
# profile_path             41047
# movie_id                 41047
# dtype: int64

# %%
# Eliminar columnas con más del 50% de datos faltantes
threshold = len(df_merged) * 0.5
df_cleaned = df_merged.dropna(thresh=threshold, axis=1)

# %%
# Eliminar filas con una cantidad significativa de datos faltantes
df_cleaned = df_cleaned.dropna(thresh=len(df_cleaned.columns) * 0.5, axis=0)

# %%
# Imputar datos faltantes con la mediana (para columnas numéricas)
num_cols = df_cleaned.select_dtypes(include=['float64', 'int64']).columns
df_cleaned[num_cols] = df_cleaned[num_cols].fillna(df_cleaned[num_cols].median())

# %%
# Imputar datos faltantes con la moda (para columnas categóricas)
cat_cols = df_cleaned.select_dtypes(include=['object']).columns
df_cleaned[cat_cols] = df_cleaned[cat_cols].fillna(df_cleaned[cat_cols].mode().iloc[0])

# %%
df_cleaned.isnull().sum()
# Out:
# budget                  0
# genres                  0
# id_x                    0
# original_language       0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
def get_director(df, nombre_director: str):
    # Filtrar por las filas que contienen información del equipo (crew)
    df_director = df[df['director'].str.lower() == nombre_director.lower()]

    # Crear variables para almacenar la cantidad de películas y el retorno total
    total_peliculas = df_director.shape[0]
    total_retorno = (df_director['revenue'] - df_director['budget']).sum()
    peliculas_info = df_director[['title', 'release_date', 'revenue', 'budget']].copy()
    peliculas_info['retorno_individual'] = peliculas_info['revenue'] - peliculas_info['budget']
    peliculas_info.rename(columns={'title': 'titulo', 'release_date': 'fecha_lanzamiento', 'revenue': 'ganancia', 'budget': 'costo'}, inplace=True)

    # Calcular el promedio de retorno
    if total_peliculas > 0:
        promedio_retorno = total_retorno / total_peliculas
        return {
            "message": f"El director {nombre_director} ha participado de {total_peliculas} cantidad de filmaciones, el mismo ha conseguido un retorno de {total_retorno} con un promedio de {promedio_retorno} por filmación",
            "peliculas": peliculas_info.to_dict(orient='records')
        }
    else:
        return "Director no encontrado o no tiene suficientes participaciones"

# Probar la función con un nombre de director de ejemplo
director_a_probar = "Steven Spielberg"  # Cambia este valor al nombre del director que quieras probar
resultado = get_director(df_merged, director_a_probar)
print(resultado)
# Out:
# {'message': 'El director Steven Spielberg ha participado de 4 cantidad de filmaciones, el mismo ha conseguido un retorno de 16750919.0 con un promedio de 4187729.75 por filmación', 'peliculas': [{'titulo': 'I Wanna Hold Your Hand', 'fecha_lanzamiento': '1978-04-20', 'ganancia': 0.0, 'costo': 2700000, 'retorno_individual': -2700000.0}, {'titulo': 'Twilight Zone: The Movie', 'fecha_lanzamiento': '1983-06-24', 'ganancia': 29450919.0, 'costo': 10000000, 'retorno_individual': 19450919.0}, {'titulo': 'Taken', 'fecha_lanzamiento': '2002-12-02', 'ganancia': 0.0, 'costo': 0, 'retorno_individual': 0.0}, {'titulo': 'Something Evil', 'fecha_lanzamiento': '1972-01-21', 'ganancia': 0.0, 'costo': 0, 'retorno_individual': 0.0}]}

# %%
df_merged.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres   id_x original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844                en
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602                en
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357                en
# 4                     [{'id': 35, 'name': 'Comedy'}]  11862                en
#
#                                             overview  popularity  \
# ...

# %%
df_merged.columns
# Out:
# Index(['belongs_to_collection', 'budget', 'genres', 'id_x',
#        'original_language', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'cast', 'crew', 'credit_id', 'department', 'gender',
#        'id_y', 'job', 'director', 'profile_path', 'movie_id'],
#       dtype='object')

# %%
df_combines.columns
# Out:
# Index(['belongs_to_collection', 'budget', 'genres', 'id', 'original_language',
#        'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'cast', 'crew'],
#       dtype='object')

# %%
df_merged.to_parquet('movies_dataset_cleaned.parquet')
