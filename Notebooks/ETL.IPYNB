# %%
import pandas as pd
import json
import numpy as np
# Cargar el dataset
df = pd.read_csv('movies_dataset.csv')
# Out:
# C:\Users\jeiso\AppData\Local\Temp\ipykernel_16636\3257255684.py:5: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('movies_dataset.csv')

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
print(df['belongs_to_collection'].head(12))
# Out:
# 0     {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                   NaN
# 2     {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                   NaN
# 4     {'id': 96871, 'name': 'Father of the Bride Col...
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9     {'id': 645, 'name': 'James Bond Collection', '...
# 10                                                  NaN
# 11                                                  NaN
# Name: belongs_to_collection, dtype: object

# %%
# Mostrar las primeras filas de la columna belongs_to_collection
print(df['belongs_to_collection'].head())
# Out:
# 0    {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                  NaN
# 2    {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                  NaN
# 4    {'id': 96871, 'name': 'Father of the Bride Col...
# Name: belongs_to_collection, dtype: object

# %%
# Función para convertir strings en diccionarios si es necesario
def convert_to_dict(x):
    if pd.isnull(x):
        return {}
    try:
        return ast.literal_eval(x)
    except (ValueError, SyntaxError):
        return {}

# %%
import ast
# Convertir strings en diccionarios
df['belongs_to_collection'] = df['belongs_to_collection'].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else {})

# %%
# Aplicar la función a la columna belongs_to_collection
df['belongs_to_collection'] = df['belongs_to_collection'].apply(convert_to_dict)

# %%
# Crear nuevas columnas
df['collection_id'] = df['belongs_to_collection'].apply(lambda x: x.get('id') if isinstance(x, dict) else None)
df['collection_name'] = df['belongs_to_collection'].apply(lambda x: x.get('name') if isinstance(x, dict) else None)
df['collection_poster_path'] = df['belongs_to_collection'].apply(lambda x: x.get('poster_path') if isinstance(x, dict) else None)
df['collection_backdrop_path'] = df['belongs_to_collection'].apply(lambda x: x.get('backdrop_path') if isinstance(x, dict) else None)

# %%
# Eliminar la columna original
df.drop(columns=['belongs_to_collection'], inplace=True)

# %%
# Verificar el resultado
print(df[['collection_id', 'collection_name', 'collection_poster_path', 'collection_backdrop_path']].head())
# Out:
#   collection_id collection_name collection_poster_path  \
# 0          None            None                   None
# 1          None            None                   None
# 2          None            None                   None
# 3          None            None                   None
# 4          None            None                   None
#
#   collection_backdrop_path
# 0                     None
# 1                     None
# 2                     None
# 3                     None
# 4                     None

# %%
df.head()
# Out:
#    adult    budget                                             genres  \
# 0  False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4  False         0                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# ...

# %%
# Mostrar las primeras filas de la columna production_companies
print(df['production_companies'].head())
# Out:
# 0       [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1    [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2    [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3    [{'name': 'Twentieth Century Fox Film Corporat...
# 4    [{'name': 'Sandollar Productions', 'id': 5842}...
# Name: production_companies, dtype: object

# %%
# Función para convertir strings en listas de diccionarios
def convert_to_list_of_dicts(x):
    if pd.isnull(x):
        return []
    try:
        return ast.literal_eval(x)
    except (ValueError, SyntaxError):
        return []

# Aplicar la función a la columna production_companies
df['production_companies'] = df['production_companies'].apply(convert_to_list_of_dicts)

# %%
# Función para extraer información de la lista de diccionarios
def get_company_info(companies, index, key):
    if isinstance(companies, list) and len(companies) > index:
        return companies[index].get(key, None)
    
    return None

# Crear nuevas columnas
df['production_company_1_id'] = df['production_companies'].apply(lambda x: get_company_info(x, 0, 'id'))
df['production_company_1_name'] = df['production_companies'].apply(lambda x: get_company_info(x, 0, 'name'))
df['production_company_2_id'] = df['production_companies'].apply(lambda x: get_company_info(x, 1, 'id'))
df['production_company_2_name'] = df['production_companies'].apply(lambda x: get_company_info(x, 1, 'name'))

# %%
# Eliminar la columna original
df.drop(columns=['production_companies'], inplace=True)

# %%
df.head()
# Out:
#    adult    budget                                             genres  \
# 0  False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4  False         0                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   adult                      45466 non-null  object
#  1   budget                     45466 non-null  object
#  2   genres                     45466 non-null  object
#  3   homepage                   7782 non-null   object
#  4   id                         45466 non-null  object
#  5   imdb_id                    45449 non-null  object
#  6   original_language          45455 non-null  object
#  7   original_title             45466 non-null  object
#  8   overview                   44512 non-null  object
#  9   popularity                 45461 non-null  object
#  10  poster_path                45080 non-null  object
#  11  production_countries       45463 non-null  object
#  12  release_date               45379 non-null  object
# ...

# %%
# Función para desanidar los géneros
def extract_genres(genre_list):
    if pd.isna(genre_list) or genre_list == '[]':
        return ''
    else:
        # Reemplazar comillas simples por comillas dobles
        genre_list = genre_list.replace("'", '"')
        genres = json.loads(genre_list)
        return ', '.join([genre['name'] for genre in genres])

# Aplicar la función a la columna 'genres'
df['genres'] = df['genres'].apply(extract_genres)

# Mostrar el DataFrame resultante
print(df)
# Out:
#        adult    budget                      genres  \
# 0      False  30000000   Animation, Comedy, Family
# 1      False  65000000  Adventure, Fantasy, Family
# 2      False         0             Romance, Comedy
# 3      False  16000000      Comedy, Drama, Romance
# 4      False         0                      Comedy
# ...      ...       ...                         ...
# 45461  False         0               Drama, Family
# 45462  False         0                       Drama
# 45463  False         0     Action, Drama, Thriller
# 45464  False         0
# 45465  False         0
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...

# %%
df.head()
# Out:
#    adult    budget                      genres  \
# 0  False  30000000   Animation, Comedy, Family
# 1  False  65000000  Adventure, Fantasy, Family
# 2  False         0             Romance, Comedy
# 3  False  16000000      Comedy, Drama, Romance
# 4  False         0                      Comedy
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   adult                      45466 non-null  object
#  1   budget                     45466 non-null  object
#  2   genres                     45466 non-null  object
#  3   homepage                   7782 non-null   object
#  4   id                         45466 non-null  object
#  5   imdb_id                    45449 non-null  object
#  6   original_language          45455 non-null  object
#  7   original_title             45466 non-null  object
#  8   overview                   44512 non-null  object
#  9   popularity                 45461 non-null  object
#  10  poster_path                45080 non-null  object
#  11  production_countries       45463 non-null  object
#  12  release_date               45379 non-null  object
# ...

# %%
df[['genres']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   genres  45466 non-null  object
# dtypes: object(1)
# memory usage: 355.3+ KB

# %%
df[['genres']].head()
# Out:
#                        genres
# 0   Animation, Comedy, Family
# 1  Adventure, Fantasy, Family
# 2             Romance, Comedy
# 3      Comedy, Drama, Romance
# 4                      Comedy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   adult                      45466 non-null  object
#  1   budget                     45466 non-null  object
#  2   genres                     45466 non-null  object
#  3   homepage                   7782 non-null   object
#  4   id                         45466 non-null  object
#  5   imdb_id                    45449 non-null  object
#  6   original_language          45455 non-null  object
#  7   original_title             45466 non-null  object
#  8   overview                   44512 non-null  object
#  9   popularity                 45461 non-null  object
#  10  poster_path                45080 non-null  object
#  11  production_countries       45463 non-null  object
#  12  release_date               45379 non-null  object
# ...

# %%
# Rellenar valores nulos de revenue 
df['revenue'] = df['revenue'].fillna(0)

# %%
#Rellenar valores nulos de budget
df['budget'] = df['budget'].fillna(0)

# %%
# Eliminar filas con valores nulos en release_date
df = df.dropna(subset=['release_date'])

# %%
df.head(10)
# Out:
#    adult    budget                            genres  \
# 0  False  30000000         Animation, Comedy, Family
# 1  False  65000000        Adventure, Fantasy, Family
# 2  False         0                   Romance, Comedy
# 3  False  16000000            Comedy, Drama, Romance
# 4  False         0                            Comedy
# 5  False  60000000    Action, Crime, Drama, Thriller
# 6  False  58000000                   Comedy, Romance
# 7  False         0  Action, Adventure, Drama, Family
# 8  False  35000000       Action, Adventure, Thriller
# 9  False  58000000       Adventure, Action, Thriller
#
#                                        homepage     id    imdb_id  \
# 0          http://toystory.disney.com/toy-story    862  tt0114709
# 1                                           NaN   8844  tt0113497
# 2                                           NaN  15602  tt0113228
# 3                                           NaN  31357  tt0114885
# ...

# %%
df[['release_date']].head()
# Out:
#   release_date
# 0   1995-10-30
# 1   1995-12-15
# 2   1995-12-22
# 3   1995-12-22
# 4   1995-02-10

# %%
# Asegurarse de que las fechas estén en el formato AAAA-mm-dd y crear la columna release_year
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')
df = df.dropna(subset=['release_date'])  # Eliminar filas donde release_date no es una fecha válida
df['release_year'] = df['release_date'].dt.year

# %%
# Eliminar filas con valores nulos en release_date
df = df.dropna(subset=['release_date'])

# %%
# Convertir las columnas 'revenue' y 'budget' a tipo numérico y manejar errores
df['revenue'] = pd.to_numeric(df['revenue'], errors='coerce').fillna(0)
df['budget'] = pd.to_numeric(df['budget'], errors='coerce').fillna(0)

# Verificar los tipos de datos para asegurarnos de que la conversión fue exitosa
df.dtypes
# Out:
# adult                                object
# budget                                int64
# genres                               object
# homepage                             object
# id                                   object
# imdb_id                              object
# original_language                    object
# original_title                       object
# overview                             object
# popularity                           object
# poster_path                          object
# production_countries                 object
# release_date                 datetime64[ns]
# revenue                             float64
# runtime                             float64
# spoken_languages                     object
# status                               object
# tagline                              object
# title                                object
# video                                object
# vote_average                        float64
# ...

# %%
df[['budget']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45376 entries, 0 to 45465
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   budget  45376 non-null  int64
# dtypes: int64(1)
# memory usage: 709.0 KB

# %%
# Crear la columna return (retorno de inversión)
df['return'] = df.apply(lambda x: x['revenue'] / x['budget'] if x['budget'] > 0 else 0, axis=1)

# %%
# Eliminar las columnas que no serán utilizadas
data_use = df.drop(columns=['video', 'imdb_id', 'adult', 'original_title', 'poster_path', 'homepage'])

# %%
data_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45376 entries, 0 to 45465
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   budget                     45376 non-null  int64
#  1   genres                     45376 non-null  object
#  2   id                         45376 non-null  object
#  3   original_language          45365 non-null  object
#  4   overview                   44435 non-null  object
#  5   popularity                 45376 non-null  object
#  6   production_countries       45376 non-null  object
#  7   release_date               45376 non-null  datetime64[ns]
#  8   revenue                    45376 non-null  float64
#  9   runtime                    45130 non-null  float64
#  10  spoken_languages           45376 non-null  object
#  11  status                     45296 non-null  object
#  12  tagline                    20398 non-null  object
# ...

# %%
df_credits = pd.read_csv('credits.csv')

# %%
df_credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
# Convertir la columna 'id' a string en ambos dataframes
df['id'] = df['id'].astype(str)
df_credits['id'] = df_credits['id'].astype(str)

# %%
# Verificar las conversiones
print(df['id'].dtypes)
print(df_credits['id'].dtypes)
# Out:
# object
# object

# %%
# Combinar ambos DataFrames en base al 'id'
df_combined = pd.merge(df, df_credits, on='id', how='inner')

# %%
df_combined.head()
# Out:
#    adult    budget                      genres  \
# 0  False  30000000   Animation, Comedy, Family
# 1  False  65000000  Adventure, Fantasy, Family
# 2  False         0             Romance, Comedy
# 3  False  16000000      Comedy, Drama, Romance
# 4  False         0                      Comedy
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
# ...

# %%
# Función para desanidar y manejar errores
def extract_cast_or_crew(column):
    if pd.isna(column) or column == '[]':
        return np.nan
    else:
        try:
            items = json.loads(column.replace("'", '"'))
            return ', '.join([item['name'] for item in items])
        except json.JSONDecodeError:
            return np.nan  # Reemplazar con NaN si hay un error en el JSON

# %%
# Aplicar la función a las columnas 'cast' y 'crew'
df_credits['cast'] = df_credits['cast'].apply(extract_cast_or_crew)
df_credits['crew'] = df_credits['crew'].apply(extract_cast_or_crew)

# %%
# Contar los valores NaN
cast_errors = df_credits['cast'].isna().sum()
crew_errors = df_credits['crew'].isna().sum()

# %%
# Mostrar los valores NaN
print(f"Errores de JSON en 'cast' (NaN): {cast_errors}")
print(f"Errores de JSON en 'crew' (NaN): {crew_errors}")
# Out:
# Errores de JSON en 'cast' (NaN): 36957
# Errores de JSON en 'crew' (NaN): 40991

# %%
# Combinar ambos DataFrames en base al 'id'
df_combined = pd.merge(df, df_credits, on='id', how='inner')

# %%
# Eliminar las columnas que no serán utilizadas
df_combined = df_combined.drop(columns=['video', 'imdb_id', 'adult', 'original_title', 'poster_path', 'homepage'])

# %%
# Guardar el DataFrame combinado para referencia
df_combined.to_csv('combined_transformed_movies.csv', index=False)

# %%
# Asegurarse de que las columnas tengan los tipos de datos adecuados
df_combined['budget'] = pd.to_numeric(df_combined['budget'], errors='coerce')
df_combined['revenue'] = pd.to_numeric(df_combined['revenue'], errors='coerce')
df_combined['popularity'] = pd.to_numeric(df_combined['popularity'], errors='coerce')
df_combined['vote_count'] = pd.to_numeric(df_combined['vote_count'], errors='coerce')
df_combined['vote_average'] = pd.to_numeric(df_combined['vote_average'], errors='coerce')

# Verificar las columnas disponibles en df_combined
print(df_combined.columns)
# Out:
# Index(['belongs_to_collection', 'budget', 'genres', 'id', 'original_language',
#        'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'cast', 'crew'],
#       dtype='object')

# %%
df_combined.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres     id original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844                en
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602                en
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357                en
# 4                     [{'id': 35, 'name': 'Comedy'}]  11862                en
#
#                                             overview popularity  \
# ...

# %%
# Crear DataFrame específico para cada endpoint
df_mes = df_combined[['title', 'release_date']]
df_dia = df_combined[['title', 'release_date']]
df_votos = df_combined[['title', 'vote_count', 'vote_average']]

# %%
df_mes.to_csv('movies_by_month.csv', index=False)
df_dia.to_csv('movies_by_day.csv', index=False)
df_votos.to_csv('movies_votes.csv', index=False)

# %%
df_combined.columns
# Out:
# Index(['belongs_to_collection', 'budget', 'genres', 'id', 'original_language',
#        'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'cast', 'crew'],
#       dtype='object')

# %%
df_score = df_combined[['title', 'release_date', 'popularity']] 
df_actor = df_combined[['title', 'cast', 'revenue']] 
df_director = df_combined[['title', 'crew', 'release_date', 'revenue', 'budget']]

# %%
df_score.to_csv('movies_score.csv', index=False)
df_actor.to_csv('movies_actor.csv', index=False)
df_director.to_csv('movies_director.csv', index=False)

# %%
# Crear DataFrame específico para cada endpoint
required_columns_score = ['title', 'release_date', 'popularity']
required_columns_actor = ['title', 'cast', 'revenue']
required_columns_director = ['title', 'crew', 'release_date', 'revenue', 'budget']

# %%
# Verificar si las columnas requeridas están presentes en df_combined
missing_columns_score = [col for col in required_columns_score if col not in df_combined.columns]
missing_columns_actor = [col for col in required_columns_actor if col not in df_combined.columns]
missing_columns_director = [col for col in required_columns_director if col not in df_combined.columns]

# %%
# Imprimir las columnas faltantes si las hay
if missing_columns_score:
    print(f"Columnas faltantes para df_score: {missing_columns_score}")
if missing_columns_actor:
    print(f"Columnas faltantes para df_actor: {missing_columns_actor}")
if missing_columns_director:
    print(f"Columnas faltantes para df_director: {missing_columns_director}")

# %%
# Crear DataFrames específicos solo si todas las columnas necesarias están presentes
if not missing_columns_score:
    df_score = df_combined[required_columns_score]
    df_score.to_parquet('movies_score.parquet', index=False)
else:
    print("No se pudo crear df_score debido a columnas faltantes.")

# %%
if not missing_columns_actor:
    df_actor = df_combined[required_columns_actor]
    df_actor.to_parquet('movies_actor.parquet', index=False)
else:
    print("No se pudo crear df_actor debido a columnas faltantes.")

# %%
if not missing_columns_director:
    df_director = df_combined[required_columns_director]
    df_director.to_parquet('movies_director.parquet', index=False)
else:
    print("No se pudo crear df_director debido a columnas faltantes.")

# %%
# Crear DataFrames adicionales que no presentan problemas
df_mes = df_combined[['title', 'release_date']]
df_dia = df_combined[['title', 'release_date']]
df_votos = df_combined[['title', 'vote_count', 'vote_average']]

# Guardar los DataFrames adicionales en formato parquet
df_mes.to_parquet('movies_by_month.parquet', index=False)
df_dia.to_parquet('movies_by_day.parquet', index=False)
df_votos.to_parquet('movies_votes.parquet', index=False)

# %%
df_combined.to_csv('combined', index=False)

# %%
import json
import numpy as np

def extract_cast_or_crew(column):
    if pd.isna(column) or column == '[]':
        return np.nan
    else:
        try:
            items = json.loads(column.replace("'", '"'))
            return ', '.join([item['name'] for item in items])
        except json.JSONDecodeError:
            return np.nan  # Reemplazar con NaN si hay un error en el JSON
